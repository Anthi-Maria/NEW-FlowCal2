# %%
import FlowCal

s = FlowCal.io.FCSData('04-blank-A2-1.fcs')
print(s.shape)
# Out:
# (7898, 26)

# %%
print(s.channels)
# Out:
# ('FSC-H', 'FSC-A', 'SSC-H', 'SSC-A', 'FL1-H', 'FL1-A', 'FL2-H', 'FL2-A', 'FL3-H', 'FL3-A', 'FL4-H', 'FL4-A', 'FL5-H', 'FL5-A', 'FL6-H', 'FL6-A', 'FL7-H', 'FL7-A', 'FL8-H', 'FL8-A', 'FL9-H', 'FL9-A', 'FL10-H', 'FL10-A', 'FSC-Width', 'Time')

# %%
import matplotlib.pyplot as plt
plt.hist(s[:, 'FL1-H'], bins=100)
plt.show()

# %%
s_transformed = FlowCal.transform.to_rfi(s, channels='FL1-H')
s_transformed
# Out:
# FCSData([[ 1.24597002e+04,  1.02619995e+03,  3.22200012e+02, ...,
#           -5.87000008e+01,  8.43057175e+01,  0.00000000e+00],
#          [ 1.01857998e+04,  3.74350000e+03,  1.86500000e+02, ...,
#            4.40000000e+01,  3.76408478e+02,  2.51000000e+02],
#          [ 1.06314004e+04,  3.81630005e+03,  2.02199997e+02, ...,
#           -1.66500000e+02,  3.67759033e+02,  4.11000000e+02],
#          ...,
#          [ 1.28485996e+04,  1.54265000e+04,  1.62655000e+04, ...,
#            2.08199997e+02,  1.22950940e+03,  2.99406200e+06],
#          [ 1.36152002e+04,  1.01037002e+04,  1.61409004e+04, ...,
#            8.00000000e+01,  7.60286865e+02,  2.99832200e+06],
#          [ 1.43940000e+04,  1.14367002e+04,  1.21065996e+04, ...,
#           -1.56800003e+02,  8.13678711e+02,  2.99899900e+06]])

# %%
import numpy as np
bins = np.logspace(0, 4, 100)
plt.hist(s_transformed[:, 'FL1-H'], bins=bins)
plt.xscale('log')
plt.show()

# %%
s = FlowCal.io.FCSData('04-blank-A2-1.fcs')
s = FlowCal.transform.to_rfi(s)

FlowCal.plot.hist1d(s, channel='FL1-H')
plt.show()

# %%
FlowCal.plot.hist1d(s, channel='FL1-H', xscale='log', bins=1024)
plt.show()

# %%
filenames = ['04-blank-A2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-A11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-C11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-E11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames = ['04-blank-G11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.xlim((1000,10000000))
plt.show()

# %%
filenames
# Out:
# ['04-blank-G11-1.fcs',
#  '04-blank-G11-2.fcs',
#  '04-blank-G11-3.fcs',
#  '04-blank-G11-4.fcs']
